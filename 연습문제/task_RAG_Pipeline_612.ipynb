# %% [markdown]
# #### 6.12.목 RAG 수행
# - 문제 3-1 :  콘텐츠분쟁해결 RAG 시스템
# - 콘텐츠분쟁해결 사례집을 활용한 법률 자문 RAG 시스템을 순차적으로 구축하는 실습입니다.

# %%
import os
from dotenv import load_dotenv

load_dotenv()
UPSTAGE_API_KEY= os.getenv("OPENAI_API_KEY")
print(UPSTAGE_API_KEY[:2])
# Out:
# sk

# %%
import os
from langchain_openai.embeddings import OpenAIEmbeddings  # OpenAI 임베딩 사용
from langchain.text_splitter import RecursiveCharacterTextSplitter  # 텍스트 분할기
from langchain_community.vectorstores import FAISS  # 벡터 DB (FAISS) 사용
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate

# PDF 파일 경로 설정
pdf_filepath = '../data/콘텐츠분쟁해결_사례.pdf'

# 파일 존재 여부 확인 (파일이 없으면 오류 발생)
if not os.path.exists(pdf_filepath):
    raise FileNotFoundError(f"파일을 찾을 수 없습니다: {pdf_filepath}")


# PDF 파일로드
loader = PyPDFLoader(pdf_filepath)
docs = loader.load()
# 총 페이지 로드
print(f"총 {len(docs)}페이지 로드 완료", type(docs[0]))

# 1단계 : 문서 분할 설정
pythontext_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,        #  법률 사례는 1200-1800자 권장
    chunk_overlap=300,      #  사례 맥락 보존을 위해 200-400자
    separators=[
        "\n【사건개요】",     #  법률 문서 섹션 구분자
        "\n【쟁점사항】",     #  쟁점 부분 구분
        "\n【처리경위】",     #  처리 과정 구분
        "\n【처리결과】",     #  결과 부분 구분
        "\n■", "\n\n", "\n", ".", " ", ""
    ]
)

chunks = pythontext_splitter.split_documents(docs)

#2단계: 임베딩 모델 설정 
pythonembeddings = OpenAIEmbeddings(
    model="text-embedding-3-large",  #  한국어 법률 용어에 최적
    dimensions=1536                  #  고성능 임베딩 차원
)

# FAISS 백터 스토어에 저장하기
vectorstore = FAISS.from_documents(chunks, pythonembeddings)

#3단계: 검색기 설정 
pythonretriever = vectorstore.as_retriever(
    search_type="similarity",        #  또는 "mmr" (다양성 고려시)
    search_kwargs={"k": 5}          #  상위 5개 관련 사례 검색
)
print(" Retriever 설정 완료")


#4단계: LLM 설정 
pythonllm = ChatOpenAI(
    model="gpt-4o",                 #  또는 "gpt-4o-mini" (경제적)
    temperature=0.2,                #  법률 조언은 정확성 중시
    max_tokens=2000                 #  충분한 답변 길이
)

#5단계: 법률 자문 프롬프트 작성 
pythonprompt_template = """
당신은 콘텐츠 분야 전문 법률 자문사입니다. 
아래 분쟁조정 사례들을 바탕으로 정확하고 전문적인 법률 조언을 제공해주세요.

관련 분쟁사례:
{context}

상담 내용: {question}

답변 가이드라인:
1. 제시된 사례들을 근거로 답변하세요                    # 사례 기반 답변
2. 관련 법령이나 조항이 있다면 명시하세요               # 법적 근거 제시
3. 비슷한 사례의 처리경위와 결과를 참고하여 설명하세요    # 판례 참조
4. 실무적 해결방안을 단계별로 제시하세요               #  실무 가이드
5. 사례에 없는 내용은 "제시된 사례집에서는 확인할 수 없습니다"라고 명시하세요  #  한계 인정

전문 법률 조언:"""

# 프롬프트 객체화
prompt = PromptTemplate(
    template=pythonprompt_template,
    input_variables=["context", "question"]
)

#6단계: QA 체인 생성 
pythonqa_chain = RetrievalQA.from_chain_type(
    llm=pythonllm,                        #  위에서 설정한 LLM
    chain_type="stuff",             #  문서들을 하나로 합쳐서 처리
    retriever=pythonretriever,            #  위에서 설정한 검색기
    chain_type_kwargs={"prompt": prompt},  #  법률 자문 프롬프트
    return_source_documents=True    #  참조 문서도 함께 반환
)

#7단계: 테스트 질문 작성 
pythontest_questions = [
    "온라인 게임에서 시스템 오류로 아이템이 사라졌는데, 게임회사가 복구를 거부하고 있습니다. 어떻게 해결할 수 있나요?",
    "인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있습니다. 정당한가요?",
    "무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?",
    "미성년자가 부모 동의 없이 게임 아이템을 구매했습니다. 환불받을 수 있는 방법이 있나요?",
    "온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶습니다. 가능한가요?"
]

#8단계: 분쟁 유형 분류 함수 ( 선택 )
def classify_dispute_type(query):
    game_keywords = ["게임", "아이템", "계정", "캐릭터", "레벨", "길드", "온라인게임"]
    elearning_keywords = ["강의", "온라인교육", "이러닝", "수강", "환불", "화상교육"]
    web_keywords = ["웹사이트", "무료체험", "자동결제", "구독", "사이트"]
    
    query_lower = query.lower()
    
    if any(keyword in query_lower for keyword in game_keywords):
        return "게임"
    elif any(keyword in query_lower for keyword in elearning_keywords):
        return "이러닝"
    elif any(keyword in query_lower for keyword in web_keywords):
        return "웹콘텐츠"
    else:
        return "기타"


# 질문
for i, question in enumerate(pythontest_questions, 1):
    print(f" 질문 {i}/5 : {question}")

    dispute_type = classify_dispute_type(question)
    print(f" 분쟁 유형: {dispute_type}")

    print(" 답변 생성 중...")
    
    # RAG 실행
    full_question = f"[{dispute_type}] {question}"
    result = pythonqa_chain.invoke({"query": full_question})
    #result = pythonqa_chain.invoke({"query": question})
    answer = result["result"]
    source_docs = result["source_documents"]
    
    print(f"\n 답변:")
    print("-" * 50)
    print(answer)
    
    # 참조 문서 정보
    print(f"\n 참조 문서:")
    for j, doc in enumerate(source_docs[:3], 1):
        page = doc.metadata.get('page', 'N/A')
        preview = doc.page_content[:80].replace('\n', ' ')
        print(f"   {j}. 페이지 {page}: {preview}...")
    
    print("\n" + "-" * 40)
# Out:
# 총 109페이지 로드 완료 <class 'langchain_core.documents.base.Document'>
#  Retriever 설정 완료
#  질문 1/5 : 온라인 게임에서 시스템 오류로 아이템이 사라졌는데, 게임회사가 복구를 거부하고 있습니다. 어떻게 해결할 수 있나요?
#  분쟁 유형: 게임
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# 온라인 게임에서 시스템 오류로 인해 아이템이 사라진 경우, 게임회사가 복구를 거부하는 상황에 대한 법률 조언을 다음과 같이 제공합니다.
#
# 1. **사례 기반 답변**:
#    - 제시된 사례 중 2006년 사례에서는 시스템 오류로 아이템이 소멸된 경우에 대해 게임 회사가 계정 명의자가 아니면 복구 처리가 불가하다고 안내하였습니다. 이는 계정 명의와 관련된 문제로, 계정 명의자가 직접 복구 신청을 해야 한다는 점을 강조하고 있습니다.
#    - 2009년 사례에서는 시스템 오류로 인한 게임머니 소실에 대해 시스템 오류가 발생하지 않았다고 판단하여 복구를 거부한 사례가 있습니다. 이는 시스템 오류의 발생 여부를 입증하는 것이 중요하다는 점을 보여줍니다.
#
# 2. **법적 근거 제시**:
#    - 일반적으로 온라인 게임의 이용약관은 계약의 일부로 간주되며, 이용약관에 명시된 내용에 따라 분쟁이 해결됩니다. 따라서 이용약관을 꼼꼼히 검토하여 시스템 오류에 대한 복구 정책이 어떻게 규정되어 있는지 확인해야 합니다.
#
# 3. **판례 참조**:
#    - 2008년 사례에서는 보안 서비스 미작동으로 인한 아이템 도난에 대해 게임사가 복구를 해준 사례가 있습니다. 이는 게임사의 서비스 미작동이 인정된 경우 복구가 가능하다는 점을 시사합니다.
#
# 4. **실무 가이드**:
#    - **이용약관 검토**: 먼저 게임사의 이용약관을 검토하여 시스템 오류로 인한 아이템 소실에 대한 복구 정책이 어떻게 규정되어 있는지 확인합니다.
#    - **증거 수집**: 시스템 오류가 발생했음을 입증할 수 있는 증거(예: 오류 발생 시각, 스크린샷, 다른 사용자들의 유사한 불만 등)를 수집합니다.
#    - **공식적인 이의제기**: 게임사에 공식적으로 이의제기를 하고, 시스템 오류로 인한 아이템 소실에 대한 복구를 요청합니다. 이때, 수집한 증거를 함께 제출합니다.
#    - **소비자 보호 기관 상담**: 게임사가 복구를 거부할 경우, 한국소비자원 등 소비자 보호 기관에 상담을 요청하여 중재를 받을 수 있습니다.
#
# 5. **한계 인정**:
#    - 제시된 사례집에서는 시스템 오류로 인한 아이템 소실에 대해 게임사가 복구를 거부하는 경우에 대한 구체적인 법적 해결책은 확인할 수 없습니다. 추가적인 법적 조언이 필요할 경우, 전문 변호사와 상담하는 것이 좋습니다.
#
# 이러한 단계들을 통해 문제를 해결할 수 있으며, 필요시 법적 조치를 고려할 수 있습니다.
#
#  참조 문서:
#    1. 페이지 8: 1. 게임 3 게임1 ■ 1-가-1) 한국소비자원 조정전 상담사례2006_시스템 오류로 소멸된 아이템 복구 요구【사건개요】신청인은 피신청인이 제...
#    2. 페이지 30: 1. 게임 25 ■ 1-가-1) 한국소비자원 조정전 상담사례2009_해킹으로 손실된 아이템 복구 요청【사건개요】피청구인이 제공하는 게임서비스 가...
#    3. 페이지 28: 1. 게임 23 ■ 1-가-1) 한국소비자원 조정전 상담사례2009_시스템 오류로 인한 손실 아이템 복구 요구【사건개요】신청인은 2009. 9....
#
# ----------------------------------------
#  질문 2/5 : 인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있습니다. 정당한가요?
#  분쟁 유형: 이러닝
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# 인터넷 강의를 중도 해지하려고 할 때 과도한 위약금을 요구받는 상황에 대한 법률 조언을 드리겠습니다. 제시된 사례들을 근거로 하여 답변을 구성하겠습니다.
#
# 1. **사례 기반 답변**:
#    - 제시된 사례들에서 공통적으로 다루어진 쟁점은 계약 해지 시 위약금의 적정성입니다. 특히, 2007년과 2010년의 사례에서는 피신청인이 과도한 위약금을 공제하려고 했으나, 소비자분쟁해결기준에 따라 해지일까지의 이용일수에 해당하는 금액과 총 이용금액의 10%를 공제 후 환급하도록 규정되어 있습니다.
#
# 2. **법적 근거 제시**:
#    - 관련 법령으로는 "방문판매 등에 관한 법률" 제29조(계약의 해지)와 소비자분쟁해결기준(공정위고시, 인터넷콘텐츠업)이 있습니다. 이 법령들은 계약 해지 시 소비자가 부담해야 할 위약금의 기준을 제시하고 있습니다.
#
# 3. **판례 참조**:
#    - 2010년 사례에서는 피신청인의 환불기준이 웹사이트에서 쉽게 인식하기 어려운 방식으로 제공되었고, 신청인이 온라인 동영상 강의를 전혀 이용하지 않았음에도 불구하고 전혀 환불하지 않는 것은 타당하지 않다고 판단되었습니다. 따라서, 당사자 간의 상호 양보를 통해 환불금액을 조정하였습니다.
#
# 4. **실무 가이드**:
#    - **계약서 확인**: 먼저, 계약서에 명시된 환불 및 위약금 조항을 확인하세요.
#    - **소비자분쟁해결기준 검토**: 소비자분쟁해결기준에 따라 해지일까지의 이용일수에 해당하는 금액과 총 이용금액의 10%를 공제 후 환급받을 수 있는지 확인하세요.
#    - **공정위 고시 확인**: 공정거래위원회의 고시 내용을 참고하여 위약금이 과도한지 판단하세요.
#    - **조정 신청**: 위약금이 과도하다고 판단되면, 한국소비자원에 분쟁조정을 신청할 수 있습니다.
#    - **협상**: 피신청인과의 협상을 통해 상호 양보를 통한 조정안을 마련해 보세요.
#
# 5. **한계 인정**:
#    - 제시된 사례집에서는 특정한 계약 조건이나 개별 상황에 대한 세부적인 정보는 확인할 수 없습니다. 따라서, 구체적인 상황에 따라 법률 전문가의 추가적인 상담을 받는 것이 좋습니다.
#
# 이러한 절차를 통해 과도한 위약금 요구에 대해 적절히 대응할 수 있을 것입니다. 추가적인 법률 자문이 필요하다면, 관련 전문가와 상담하시기를 권장합니다.
#
#  참조 문서:
#    1. 페이지 3: . 이러닝···········································································...
#    2. 페이지 62: 2. 이러닝 57 ■ 2-가 한국소비자원 조정결정례2007_인터넷교육서비스 중도해지 요구【사건개요】청구인은 2006. 2. 8. 피청구인이 운영...
#    3. 페이지 70: 2. 이러닝 65 ■ 2-가 한국소비자원 조정결정례2010_화상불량으로 중도 해지한 인터넷강의 환급 요구【사건개요】신청인은 2008. 12. 3...
#
# ----------------------------------------
#  질문 3/5 : 무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?
#  분쟁 유형: 이러닝
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# 무료체험 후 자동으로 유료전환되어 요금이 청구된 경우, 환불 가능 여부에 대한 법률 조언은 다음과 같습니다.
#
# 1. **사례 기반 답변**:
#    - 제시된 사례들에서 공통적으로 다루고 있는 것은 계약 해지 및 환불 요청 시의 절차와 기준입니다. 특히, 계약 해지 시 소비자에게 불리한 조건이나 과도한 위약금이 부과되지 않도록 하는 것이 중요합니다.
#
# 2. **법적 근거 제시**:
#    - **방문판매 등에 관한 법률 제29조**: 계약의 해지에 관한 규정으로, 소비자는 언제든지 계약을 해지할 수 있습니다.
#    - **방문판매 등에 관한 법률 제30조**: 계약 해지 시 소비자에게 과도한 위약금을 청구할 수 없으며, 실제 공급된 서비스에 대한 대가를 초과하여 수령한 대금의 반환을 거부할 수 없습니다.
#    - **소비자기본법에 따른 소비자분쟁해결기준**: 인터넷 콘텐츠업에 대한 환불 기준을 명시하고 있습니다.
#
# 3. **판례 참조**:
#    - 사례 2-가(2010_온라인교육 서비스 계약 해지)에 따르면, 계약 해지 시 과도한 위약금이 부과되지 않도록 하고, 실제 이용한 기간에 대한 요금만 공제 후 환불이 이루어져야 한다는 점이 강조되었습니다.
#    - 사례 2-가(2007_온라인통신교육서비스 대금 환급 요구2)에서는 계약 체결 시 충분한 정보 제공이 이루어지지 않았을 경우, 위약금이 과도하다고 판단될 수 있음을 보여줍니다.
#
# 4. **실무 가이드**:
#    - **계약 내용 확인**: 무료체험 후 자동 유료전환에 대한 명확한 고지가 있었는지, 계약서나 약관을 확인하세요.
#    - **환불 요청**: 서비스 제공자에게 환불을 요청하고, 계약 해지 의사를 명확히 전달하세요.
#    - **소비자 보호 기관에 문의**: 환불이 거부될 경우, 한국소비자원 등 관련 기관에 분쟁 조정을 신청할 수 있습니다.
#    - **법적 조치 고려**: 필요시 법률 전문가의 도움을 받아 법적 조치를 고려하세요.
#
# 5. **한계 인정**:
#    - 제시된 사례집에서는 무료체험 후 자동 유료전환에 대한 구체적인 사례는 확인할 수 없습니다. 따라서, 구체적인 상황에 따라 추가적인 법률 자문이 필요할 수 있습니다.
#
# 이러한 조언을 바탕으로, 귀하의 상황에 맞는 적절한 조치를 취하시기 바랍니다.
#
#  참조 문서:
#    1. 페이지 94: 2. 이러닝 89 상기 내용을 살펴보면, 신청인은 청약철회 기간을 지났으므로 위 계약의 청약을 철회할 수는 없는 것으로 보인다. 피신청인은 위 ...
#    2. 페이지 3: . 이러닝···········································································...
#    3. 페이지 74: 2. 이러닝 69 ■ 2-가 한국소비자원 조정결정례2010_온라인교육 서비스 계약 해지에 따른 이용요금 환급 요구【사건개요】신청인은 2009. ...
#
# ----------------------------------------
#  질문 4/5 : 미성년자가 부모 동의 없이 게임 아이템을 구매했습니다. 환불받을 수 있는 방법이 있나요?
#  분쟁 유형: 게임
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# 미성년자가 부모의 동의 없이 게임 아이템을 구매한 경우, 환불을 받을 수 있는 가능성은 다음과 같은 법적 근거와 사례를 통해 검토할 수 있습니다.
#
# 1. **법적 근거**:
#    - **민법 제5조**: 미성년자의 법률 행위는 원칙적으로 법정대리인의 동의를 필요로 하며, 동의 없이 이루어진 행위는 취소할 수 있습니다.
#    - **민법 제741조**: 부당이득 반환 청구에 관한 조항으로, 계약 없이 이루어진 결제는 부당이득으로 간주될 수 있습니다.
#    - **민법 제753조 및 제755조**: 미성년자의 책임능력과 그 감독자의 책임에 관한 규정입니다.
#
# 2. **사례 기반 답변**:
#    - 제시된 사례에서는 미성년자가 타인의 명의를 도용하여 결제한 경우, 법정대리인의 동의 없이 이루어진 행위로 간주되어 계약을 취소할 수 있음을 보여줍니다.
#    - 또한, 미성년자가 사술을 사용하여 성년자로 믿게 한 경우에는 취소가 어려울 수 있으나, 단순히 성년자임을 주장한 것만으로는 사술로 보지 않는다는 판례(대법원 1971. 12. 14. 선고 71다2045 판결)가 있습니다.
#
# 3. **판례 참조**:
#    - 미성년자가 부모의 동의 없이 결제한 경우, 해당 결제를 취소하고 환불받은 사례가 존재합니다. 다만, 미성년자가 적극적으로 사술을 사용한 경우에는 취소가 어려울 수 있습니다.
#
# 4. **실무적 해결방안**:
#    - **1단계**: 게임사에 미성년자의 결제 사실을 통보하고, 법정대리인의 동의 없이 이루어진 결제임을 주장하여 환불을 요청합니다.
#    - **2단계**: 게임사가 환불을 거부할 경우, 전자거래분쟁조정위원회에 분쟁 조정을 신청합니다.
#    - **3단계**: 필요한 경우, 법적 절차를 통해 민사 소송을 제기하여 부당이득 반환을 청구할 수 있습니다.
#
# 5. **한계 인정**:
#    - 제시된 사례집에서는 미성년자가 게임 아이템을 구매한 이후의 구체적인 환불 절차나 게임사의 대응 방식에 대한 정보는 확인할 수 없습니다.
#
# 이와 같은 절차를 통해 미성년자가 부모의 동의 없이 구매한 게임 아이템에 대한 환불을 받을 수 있는 가능성을 검토할 수 있습니다. 각 단계에서 법적 조언을 받는 것이 중요합니다.
#
#  참조 문서:
#    1. 페이지 50: 1. 게임 45 ■ 1-나 전자거래분쟁조정위원회 조정결정례2008_부당결제대금 반환 청구【사건개요】신청인의 자녀는 2004. 4. 22. 피신청...
#    2. 페이지 53: 콘텐츠분쟁조정 법리 연구 2부 - 타 분쟁조정사례 조사 - 48  - 피신청인  ㆍ 피신청인은 구매당시 구매자에게 전화를 하였을 당시 전화를 받...
#    3. 페이지 54: 1. 게임 49  · 민법 제103조 및 제105조 ; 반사회적 법률행위와 부당이득 · 대법원 1971. 12. 14. 선고71다2045판결 ·...
#
# ----------------------------------------
#  질문 5/5 : 온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶습니다. 가능한가요?
#  분쟁 유형: 기타
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# 온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶다는 상황에 대해 다음과 같은 법률 조언을 드립니다.
#
# 1. **사례 기반 답변**:
#    - 제시된 사례들에서 볼 수 있듯이, 온라인 교육 서비스 계약의 해지와 환불은 주로 계약의 해지 가능 여부와 환불 기준에 따라 결정됩니다. 특히, 계약 해지의 경우 소비자분쟁해결기준과 관련 법령에 따라 처리됩니다.
#
# 2. **법적 근거 제시**:
#    - **방문판매 등에 관한 법률 제29조**: 계약의 해지에 관한 규정으로, 소비자는 언제든지 계약을 해지할 수 있습니다.
#    - **방문판매 등에 관한 법률 제30조**: 계약 해지 또는 해제의 효과와 위약금에 관한 규정으로, 소비자에게 불리한 위약금은 청구할 수 없습니다.
#    - **소비자기본법에 따른 소비자분쟁해결기준**: 인터넷 콘텐츠업에 대한 환불 기준을 제시하고 있습니다.
#
# 3. **판례 참조**:
#    - 2008년 온라인 동영상 강의 계약 해지 청구 사례에서는, 피신청인이 환불 기준을 수강률에 따라 정했으나, 신청인의 해지 요청을 받아들여 이용일수에 따른 금액을 공제 후 환불하였습니다.
#    - 2010년 온라인교육 서비스 계약 해지 사례에서는, 계약 해지 시 소비자에게 불리한 위약금을 청구할 수 없다는 점을 들어, 피신청인의 과도한 공제 주장을 받아들이지 않았습니다.
#
# 4. **실무 가이드**:
#    - **1단계**: 계약서와 약관을 검토하여 해지 및 환불 조건을 확인하세요.
#    - **2단계**: 서비스가 광고와 다르게 제공되었다는 증거를 수집하세요. (예: 광고 자료, 실제 제공된 서비스 내용)
#    - **3단계**: 사업자에게 계약 해지 의사를 서면으로 통보하고, 소비자분쟁해결기준에 따른 환불을 요구하세요.
#    - **4단계**: 사업자가 이를 거부할 경우, 한국소비자원이나 전자거래분쟁조정위원회에 조정을 신청하세요.
#
# 5. **한계 인정**:
#    - 제시된 사례집에서는 광고와 다른 서비스 제공에 따른 계약 해지에 대한 직접적인 사례는 확인할 수 없습니다. 그러나 유사한 사례의 처리 경위를 참고하여 조언을 드렸습니다.
#
# 이러한 절차를 통해 문제를 해결할 수 있기를 바랍니다. 추가적인 법률 자문이 필요하다면 전문 변호사와 상담하시기를 권장합니다.
#
#  참조 문서:
#    1. 페이지 94: 2. 이러닝 89 상기 내용을 살펴보면, 신청인은 청약철회 기간을 지났으므로 위 계약의 청약을 철회할 수는 없는 것으로 보인다. 피신청인은 위 ...
#    2. 페이지 3: . 이러닝···········································································...
#    3. 페이지 62: 2. 이러닝 57 ■ 2-가 한국소비자원 조정결정례2007_인터넷교육서비스 중도해지 요구【사건개요】청구인은 2006. 2. 8. 피청구인이 운영...
#
# ----------------------------------------
