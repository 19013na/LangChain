# %% [markdown]
# #### 6.12.목 RAG 수행
# - 문제 3-1 :  콘텐츠분쟁해결 RAG 시스템
# - 콘텐츠분쟁해결 사례집을 활용한 법률 자문 RAG 시스템을 순차적으로 구축하는 실습입니다.

# %%
import os
from dotenv import load_dotenv

load_dotenv()
UPSTAGE_API_KEY= os.getenv("OPENAI_API_KEY")
print(UPSTAGE_API_KEY[:2])
# Out:
# sk

# %%
import os
from langchain_openai.embeddings import OpenAIEmbeddings  # OpenAI 임베딩 사용
from langchain.text_splitter import RecursiveCharacterTextSplitter  # 텍스트 분할기
from langchain_community.vectorstores import FAISS  # 벡터 DB (FAISS) 사용
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate

# PDF 파일 경로 설정
pdf_filepath = '../data/콘텐츠분쟁해결_사례.pdf'
# 파일 존재 여부 확인 (파일이 없으면 오류 발생)
if not os.path.exists(pdf_filepath):
    raise FileNotFoundError(f"파일을 찾을 수 없습니다: {pdf_filepath}")
# PDF 파일로드
loader = PyPDFLoader(pdf_filepath)
docs = loader.load()
# 총 페이지 로드
print(f"총 {len(docs)}페이지 로드 완료", type(docs[0]))


# 1단계 : 문서 분할 설정
pythontext_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,        #  법률 사례는 1200-1800자 권장
    chunk_overlap=300,      #  사례 맥락 보존을 위해 200-400자
    separators=[
        "\n【사건개요】",     #  법률 문서 섹션 구분자
        "\n【쟁점사항】",     #  쟁점 부분 구분
        "\n【처리경위】",     #  처리 과정 구분
        "\n【처리결과】",     #  결과 부분 구분
        "\n■", "\n\n", "\n", ".", " ", ""
    ]
)

chunks = pythontext_splitter.split_documents(docs)

#2단계: 임베딩 모델 설정 
pythonembeddings = OpenAIEmbeddings(
    model="text-embedding-3-large",  #  한국어 법률 용어에 최적
    dimensions=1536                  #  고성능 임베딩 차원
)
# FAISS 백터 스토어에 저장하기
vectorstore = FAISS.from_documents(chunks, pythonembeddings)


#3단계: 검색기 설정 
pythonretriever = vectorstore.as_retriever(
    search_type="similarity",        #  또는 "mmr" (다양성 고려시)
    search_kwargs={"k": 5}          #  상위 5개 관련 사례 검색
)
print(" Retriever 설정 완료")


#4단계: LLM 설정 
pythonllm = ChatOpenAI(
    model="gpt-4o",                 #  또는 "gpt-4o-mini" (경제적)
    temperature=0.2,                #  법률 조언은 정확성 중시
    max_tokens=2000                 #  충분한 답변 길이
)


#5단계: 법률 자문 프롬프트 작성 
pythonprompt_template = """
당신은 콘텐츠 분야 전문 법률 자문사입니다. 
아래 분쟁조정 사례들을 바탕으로 정확하고 전문적인 법률 조언을 제공해주세요.

관련 분쟁사례:
{context}

상담 내용: {question}

답변 가이드라인:
1. 제시된 사례들을 근거로 답변하세요                    # 사례 기반 답변
2. 관련 법령이나 조항이 있다면 명시하세요               # 법적 근거 제시
3. 비슷한 사례의 처리경위와 결과를 참고하여 설명하세요    # 판례 참조
4. 실무적 해결방안을 단계별로 제시하세요               #  실무 가이드
5. 사례에 없는 내용은 "제시된 사례집에서는 확인할 수 없습니다"라고 명시하세요  #  한계 인정

전문 법률 조언:"""


# 프롬프트 객체화
prompt = PromptTemplate(
    template=pythonprompt_template,
    input_variables=["context", "question"]
)


#6단계: QA 체인 생성 
pythonqa_chain = RetrievalQA.from_chain_type(
    llm=pythonllm,                        #  위에서 설정한 LLM
    chain_type="stuff",             #  문서들을 하나로 합쳐서 처리
    retriever=pythonretriever,            #  위에서 설정한 검색기
    chain_type_kwargs={"prompt": prompt},  #  법률 자문 프롬프트
    return_source_documents=True    #  참조 문서도 함께 반환
)


#7단계: 테스트 질문 작성 
pythontest_questions = [
    "온라인 게임에서 시스템 오류로 아이템이 사라졌는데, 게임회사가 복구를 거부하고 있습니다. 어떻게 해결할 수 있나요?",
    "인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있습니다. 정당한가요?",
    "무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?",
    "미성년자가 부모 동의 없이 게임 아이템을 구매했습니다. 환불받을 수 있는 방법이 있나요?",
    "온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶습니다. 가능한가요?"
]


#8단계: 분쟁 유형 분류 함수 ( 선택 )
def classify_dispute_type(query):
    game_keywords = ["게임", "아이템", "계정", "캐릭터", "레벨", "길드", "온라인게임"]
    elearning_keywords = ["강의", "온라인교육", "이러닝", "수강", "환불", "화상교육"]
    web_keywords = ["웹사이트", "무료체험", "자동결제", "구독", "사이트"]
    
    query_lower = query.lower()
    
    if any(keyword in query_lower for keyword in game_keywords):
        return "게임"
    elif any(keyword in query_lower for keyword in elearning_keywords):
        return "이러닝"
    elif any(keyword in query_lower for keyword in web_keywords):
        return "웹콘텐츠"
    else:
        return "기타"


# 질문
for i, question in enumerate(pythontest_questions, 1):
    print(f" 질문 {i}/5 : {question}")

    dispute_type = classify_dispute_type(question)
    print(f" 상담 내용: {dispute_type}")

    print(" 관련 사례 검색 및 법률 조언 생성 중...")
    
    # RAG 실행
    # 8단계 활용
    full_question = f"[{dispute_type}] {question}"
    result = pythonqa_chain.invoke({"query": full_question})
    #result = pythonqa_chain.invoke({"query": question})
    answer = result["result"]
    source_docs = result["source_documents"]
    
    print(f"\n 법률 자문:")
    print("-" * 50)
    print(answer)
    
    # 참조 문서 정보
    print(f"\n 참조 분쟁사례례:")
    for j, doc in enumerate(source_docs[:3], 1):
        page = doc.metadata.get('page', 'N/A')
        preview = doc.page_content[:80].replace('\n', ' ')
        print(f"   {j}. 페이지 {page}: {preview}...")
    
    print("\n" + "-" * 40)
    
print("\n RAG 시스템 테스트 완료!")
print(" 실제 분쟁 상황에서 이 시스템을 활용하여 관련 사례와 법적 근거를 빠르게 찾을 수 있습니다.")
# Out:
# 총 109페이지 로드 완료 <class 'langchain_core.documents.base.Document'>
#  Retriever 설정 완료
#  질문 1/5 : 온라인 게임에서 시스템 오류로 아이템이 사라졌는데, 게임회사가 복구를 거부하고 있습니다. 어떻게 해결할 수 있나요?
#  상담 내용: 게임
#  관련 사례 검색 및 법률 조언 생성 중...
#
#  법률 자문:
# --------------------------------------------------
# 온라인 게임에서 시스템 오류로 인해 아이템이 사라진 경우, 게임회사가 복구를 거부하는 상황에 대한 법률 조언을 다음과 같이 드립니다.
#
# 1. **사례 기반 답변**:
#    - 제시된 사례 중 2006년 사례에서는 시스템 오류로 아이템이 소멸된 경우가 있었으나, 계정 명의자가 아니면 복구가 불가하다는 결론이 나왔습니다. 이는 계정 명의와 관련된 문제로, 본인이 계정의 실소유자임을 증명하지 못한 경우 복구가 어려울 수 있음을 보여줍니다.
#    - 2009년 사례에서는 시스템 오류로 인한 게임머니 소실에 대해, 다른 사용자들에게 유사한 불만이 접수되지 않았고, 사용 내역상 문제가 없었다는 이유로 시스템 오류로 보기 어렵다는 결론이 나왔습니다.
#
# 2. **법적 근거 제시**:
#    - 게임사의 약관에 따라 시스템 오류로 인한 아이템 소실에 대한 복구 여부가 결정될 수 있습니다. 약관에 시스템 오류에 대한 보상 규정이 있는지 확인하는 것이 중요합니다.
#    - 민법 제250조와 제251조는 도품이나 유실물에 대한 반환 청구에 관한 규정을 두고 있으나, 이는 주로 물리적 재산에 대한 규정입니다. 디지털 아이템의 경우 약관과 계약에 따라 처리될 가능성이 높습니다.
#
# 3. **판례 참조**:
#    - 2009년 사례에서 시스템 오류로 인한 손실에 대해 다른 사용자들의 불만이 없고, 사용 내역상 문제가 없다는 점을 들어 시스템 오류로 인정되지 않았습니다. 이는 시스템 오류를 주장할 때, 다른 사용자들의 유사한 피해 사례나 명확한 증거가 필요함을 시사합니다.
#
# 4. **실무 가이드**:
#    - **1단계**: 게임사의 약관을 검토하여 시스템 오류로 인한 아이템 소실에 대한 복구 규정이 있는지 확인합니다.
#    - **2단계**: 시스템 오류로 인한 소실임을 증명할 수 있는 증거(예: 오류 발생 시점의 스크린샷, 로그 기록 등)를 수집합니다.
#    - **3단계**: 게임사에 공식적으로 이의제기 및 복구 요청을 합니다. 이때, 수집한 증거를 함께 제출합니다.
#    - **4단계**: 게임사가 복구를 거부할 경우, 한국소비자원이나 관련 기관에 중재를 요청할 수 있습니다.
#
# 5. **한계 인정**:
#    - 제시된 사례집에서는 시스템 오류로 인한 아이템 소실에 대한 복구가 성공적으로 이루어진 사례는 확인할 수 없습니다. 따라서, 각 사례의 구체적인 상황과 증거에 따라 결과가 달라질 수 있음을 유의해야 합니다.
#
# 이러한 조언을 바탕으로 문제를 해결하시길 바랍니다. 추가적인 법적 조언이 필요하다면, 전문 변호사와 상담하는 것도 고려해 보시기 바랍니다.
#
#  참조 분쟁사례례:
#    1. 페이지 8: 1. 게임 3 게임1 ■ 1-가-1) 한국소비자원 조정전 상담사례2006_시스템 오류로 소멸된 아이템 복구 요구【사건개요】신청인은 피신청인이 제...
#    2. 페이지 30: 1. 게임 25 ■ 1-가-1) 한국소비자원 조정전 상담사례2009_해킹으로 손실된 아이템 복구 요청【사건개요】피청구인이 제공하는 게임서비스 가...
#    3. 페이지 28: 1. 게임 23 ■ 1-가-1) 한국소비자원 조정전 상담사례2009_시스템 오류로 인한 손실 아이템 복구 요구【사건개요】신청인은 2009. 9....
#
# ----------------------------------------
#  질문 2/5 : 인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있습니다. 정당한가요?
#  상담 내용: 이러닝
#  관련 사례 검색 및 법률 조언 생성 중...
#
#  법률 자문:
# --------------------------------------------------
# 인터넷 강의를 중도 해지하려고 할 때 과도한 위약금을 요구받는 상황에 대한 법률 조언을 드리겠습니다. 제시된 사례들을 바탕으로 다음과 같이 답변드립니다.
#
# 1. **사례 기반 답변**:
#    - 제시된 사례들에서 공통적으로 다루어진 문제는 계약 해지 시 위약금의 과도성입니다. 예를 들어, 2007년 사례에서는 피신청인이 위약금, 월교육비, 화상교육비 등을 공제하고 환급하겠다고 하였으나, 소비자분쟁해결기준에 따라 해지일까지의 이용일수에 해당하는 금액과 총이용금액의 10%를 공제한 후 환급해야 한다고 결정되었습니다.
#    - 2010년 사례에서는 계약 해지의 귀책사유가 누구에게 있는지에 대한 논의가 있었으며, 실제 이용횟수와 계약기간 대비 이용기간을 기준으로 환급이 이루어져야 한다고 판단되었습니다.
#
# 2. **법적 근거 제시**:
#    - 관련 법령으로는 방문판매 등에 관한 법률 제29조(계약의 해지)와 소비자보호법 시행령 제10조가 있으며, 소비자분쟁해결기준(공정위고시, 인터넷콘텐츠업)에 따라 환급 기준이 설정되어 있습니다.
#
# 3. **판례 참조**:
#    - 2008년 사례에서는 계약서상에 표시된 금액과 실제 지불한 금액이 다를 경우, 실제 지불한 금액을 기준으로 환급해야 한다고 판단되었습니다. 또한, 중도 해지 시 별도의 환급 기준이 없을 경우 소비자분쟁해결기준에 따라 환급하는 것이 타당하다고 결정되었습니다.
#
# 4. **실무 가이드**:
#    - 계약서와 실제 지불한 금액을 확인하여 환급 기준을 명확히 하십시오.
#    - 계약 해지 시 소비자분쟁해결기준에 따라 해지일까지의 이용일수에 해당하는 금액과 총이용금액의 10%를 공제한 후 환급을 요구하십시오.
#    - 계약 해지의 귀책사유가 상대방에게 있는 경우, 이를 입증할 수 있는 증거를 수집하여 주장하십시오.
#    - 분쟁이 지속될 경우, 한국소비자원이나 관련 기관에 조정을 신청하여 해결을 도모하십시오.
#
# 5. **한계 인정**:
#    - 제시된 사례집에서는 귀하의 구체적인 상황에 대한 추가적인 정보는 확인할 수 없습니다. 따라서, 구체적인 계약 내용과 상황에 따라 법률 전문가의 추가적인 상담을 받는 것이 좋습니다.
#
# 이러한 조언이 귀하의 상황 해결에 도움이 되기를 바랍니다. 추가적인 법적 조언이 필요하시면 법률 전문가와 상담하시기 바랍니다.
#
#  참조 분쟁사례례:
#    1. 페이지 3: . 이러닝···········································································...
#    2. 페이지 62: 2. 이러닝 57 ■ 2-가 한국소비자원 조정결정례2007_인터넷교육서비스 중도해지 요구【사건개요】청구인은 2006. 2. 8. 피청구인이 운영...
#    3. 페이지 70: 2. 이러닝 65 ■ 2-가 한국소비자원 조정결정례2010_화상불량으로 중도 해지한 인터넷강의 환급 요구【사건개요】신청인은 2008. 12. 3...
#
# ----------------------------------------
#  질문 3/5 : 무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?
#  상담 내용: 이러닝
#  관련 사례 검색 및 법률 조언 생성 중...
#
#  법률 자문:
# --------------------------------------------------
# 무료체험 후 자동으로 유료전환되어 요금이 청구된 경우, 환불 가능 여부에 대한 법률 조언을 드리겠습니다.
#
# 1. **사례 기반 답변**:
#    - 제시된 사례들에서는 계약 해지 및 환불에 관한 다양한 상황들이 다루어졌습니다. 특히, 청약철회 기간이 지난 경우, 계약 해지의 의사표시와 환불 기준에 따라 환불이 이루어지는 사례들이 있습니다. 무료체험 후 자동 유료전환의 경우, 소비자가 명확히 유료전환에 대한 동의를 했는지 여부가 중요합니다.
#
# 2. **법적 근거 제시**:
#    - 「방문판매 등에 관한 법률」 제29조와 제30조는 계약의 해지 및 해제의 효과와 위약금에 대해 규정하고 있습니다. 특히, 소비자에게 불리한 계약 조항은 무효로 볼 수 있으며, 소비자기본법에 따른 소비자분쟁해결기준(공정위고시, 인터넷콘텐츠업)도 참고할 수 있습니다.
#
# 3. **판례 참조**:
#    - 사례 2-가(2010_온라인교육 서비스 계약 해지에 따른 이용요금 환급 요구)에서는 계약 해지 시 소비자에게 불리한 위약금 청구가 인정되지 않았습니다. 이는 소비자가 계약 해지를 요청할 경우, 과도한 위약금이나 불리한 조건이 적용되지 않도록 보호받을 수 있음을 시사합니다.
#
# 4. **실무 가이드**:
#    - **첫째**, 계약 체결 시 제공된 약관이나 계약서에서 무료체험 후 유료전환에 대한 명확한 설명이 있었는지 확인하세요.
#    - **둘째**, 무료체험 후 유료전환에 대한 명시적 동의가 있었는지 확인하세요. 만약 동의가 없었다면, 이는 부당한 청구로 볼 수 있습니다.
#    - **셋째**, 사업자에게 환불 요청을 하되, 계약 체결 시 제공된 정보가 불충분했음을 강조하세요.
#    - **넷째**, 사업자가 환불을 거부할 경우, 한국소비자원이나 공정거래위원회에 분쟁조정을 신청할 수 있습니다.
#
# 5. **한계 인정**:
#    - 제시된 사례집에서는 무료체험 후 자동 유료전환에 대한 직접적인 사례는 확인할 수 없습니다. 그러나 유사한 계약 해지 및 환불 사례를 통해 일반적인 법적 원칙을 적용할 수 있습니다.
#
# 이러한 조언을 바탕으로, 귀하의 상황에 맞는 적절한 조치를 취하시길 바랍니다. 추가적인 법률 자문이 필요하다면, 전문 변호사와 상담하시기를 권장합니다.
#
#  참조 분쟁사례례:
#    1. 페이지 94: 2. 이러닝 89 상기 내용을 살펴보면, 신청인은 청약철회 기간을 지났으므로 위 계약의 청약을 철회할 수는 없는 것으로 보인다. 피신청인은 위 ...
#    2. 페이지 3: . 이러닝···········································································...
#    3. 페이지 74: 2. 이러닝 69 ■ 2-가 한국소비자원 조정결정례2010_온라인교육 서비스 계약 해지에 따른 이용요금 환급 요구【사건개요】신청인은 2009. ...
#
# ----------------------------------------
#  질문 4/5 : 미성년자가 부모 동의 없이 게임 아이템을 구매했습니다. 환불받을 수 있는 방법이 있나요?
#  상담 내용: 게임
#  관련 사례 검색 및 법률 조언 생성 중...
#
#  법률 자문:
# --------------------------------------------------
# 미성년자가 부모의 동의 없이 게임 아이템을 구매한 경우, 환불을 받을 수 있는지에 대한 법률 조언을 다음과 같이 드립니다.
#
# 1. **사례 기반 답변**:
#    - 제시된 사례들에서 미성년자가 부모의 동의 없이 타인의 명의를 도용하여 결제한 경우, 해당 결제는 무효로 간주될 수 있습니다. 이는 미성년자의 법률 행위가 법정대리인의 동의 없이 이루어졌기 때문입니다.
#
# 2. **법적 근거 제시**:
#    - **민법 제5조**: 미성년자의 능력 제한 규정에 따라, 미성년자의 법률 행위는 법정대리인의 동의가 없으면 취소할 수 있습니다.
#    - **민법 제17조**: 무능력자의 사술에 관한 규정에 따라, 미성년자가 사술로써 능력자임을 믿게 한 경우에는 취소할 수 없습니다.
#    - **민법 제741조**: 부당이득의 내용에 따라, 계약 없이 결제를 받았다면 이는 부당이득으로서 반환의 대상이 됩니다.
#
# 3. **판례 참조**:
#    - 대법원 1971. 12. 14. 선고 71다2045 판결에서는 미성년자가 사술을 사용하여 능력자임을 믿게 한 경우 취소할 수 없다고 판시하였습니다. 그러나 단순히 능력자라고 칭한 것만으로는 사술로 보지 않습니다.
#
# 4. **실무 가이드**:
#    - **1단계**: 게임 회사에 미성년자의 결제 내역을 확인하고, 법정대리인의 동의 없이 이루어진 거래임을 알립니다.
#    - **2단계**: 결제 취소 및 환불 요청을 공식적으로 제출합니다. 이때, 미성년자의 법률 행위가 법정대리인의 동의 없이 이루어졌음을 강조합니다.
#    - **3단계**: 게임 회사가 환불을 거부할 경우, 전자거래분쟁조정위원회에 분쟁 조정을 신청할 수 있습니다.
#    - **4단계**: 필요시 법적 절차를 통해 부당이득 반환 청구 소송을 고려할 수 있습니다.
#
# 5. **한계 인정**:
#    - 제시된 사례집에서는 미성년자가 사술을 사용하지 않았거나, 부모의 동의 없이 결제한 경우에 대한 명확한 환불 절차는 확인할 수 없습니다. 추가적인 법적 자문이 필요할 수 있습니다.
#
# 이러한 절차를 통해 미성년자의 결제에 대한 환불을 받을 가능성을 높일 수 있습니다. 그러나 각 사례의 구체적인 상황에 따라 결과가 달라질 수 있으므로, 필요시 전문 법률가의 추가적인 자문을 받는 것이 좋습니다.
#
#  참조 분쟁사례례:
#    1. 페이지 50: 1. 게임 45 ■ 1-나 전자거래분쟁조정위원회 조정결정례2008_부당결제대금 반환 청구【사건개요】신청인의 자녀는 2004. 4. 22. 피신청...
#    2. 페이지 53: 콘텐츠분쟁조정 법리 연구 2부 - 타 분쟁조정사례 조사 - 48  - 피신청인  ㆍ 피신청인은 구매당시 구매자에게 전화를 하였을 당시 전화를 받...
#    3. 페이지 54: 1. 게임 49  · 민법 제103조 및 제105조 ; 반사회적 법률행위와 부당이득 · 대법원 1971. 12. 14. 선고71다2045판결 ·...
#
# ----------------------------------------
#  질문 5/5 : 온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶습니다. 가능한가요?
#  상담 내용: 기타
#  관련 사례 검색 및 법률 조언 생성 중...
#
#  법률 자문:
# --------------------------------------------------
# 온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶으신 경우, 다음과 같은 법률적 조언을 드릴 수 있습니다.
#
# 1. **사례 기반 답변**:
#    - 제시된 사례들에서 공통적으로 다루어진 문제는 계약 해지 시 환급금의 산정과 위약금의 적정성입니다. 특히, 서비스가 광고와 다르게 제공된 경우, 이는 계약의 중요한 사항에 대한 불이행으로 볼 수 있습니다.
#
# 2. **법적 근거 제시**:
#    - **방문판매 등에 관한 법률 제29조**: 계약의 해지에 관한 규정으로, 소비자는 언제든지 계약을 해지할 수 있습니다.
#    - **소비자기본법에 따른 소비자분쟁해결기준**: 인터넷 콘텐츠업에 대한 환급 기준을 제시하고 있습니다.
#
# 3. **판례 참조**:
#    - 사례 2-가(2007)에서는 계약 해지 시 소비자피해보상규정에 따라 '해지 일까지의 이용일수에 해당하는 금액과 총이용금액의 10% 공제 후 환급'이 이루어졌습니다.
#    - 사례 2-다(2008)에서는 환불 기준이 명확하지 않은 경우, 신의성실의 원칙에 따라 환불이 조정되었습니다.
#
# 4. **실무 가이드**:
#    - **1단계**: 계약서 및 서비스 약관을 검토하여 광고와 실제 제공된 서비스 간의 차이를 확인합니다.
#    - **2단계**: 서비스 제공자에게 계약 해지 의사를 명확히 전달하고, 환급 기준에 대해 협의합니다.
#    - **3단계**: 소비자분쟁조정위원회나 한국소비자원에 중재를 요청하여 분쟁 해결을 도모할 수 있습니다.
#    - **4단계**: 필요시 법률 전문가의 도움을 받아 소송을 고려할 수 있습니다.
#
# 5. **한계 인정**:
#    - 제시된 사례집에서는 광고와 실제 서비스 간의 차이에 대한 구체적인 판례는 확인할 수 없습니다. 다만, 일반적인 계약 불이행에 대한 법적 조치를 참고할 수 있습니다.
#
# 이러한 절차를 통해 계약 해지 및 환급 문제를 해결할 수 있을 것입니다. 추가적인 법적 조언이 필요하시면 법률 전문가와 상담하시기를 권장합니다.
#
#  참조 분쟁사례례:
#    1. 페이지 62: 2. 이러닝 57 ■ 2-가 한국소비자원 조정결정례2007_인터넷교육서비스 중도해지 요구【사건개요】청구인은 2006. 2. 8. 피청구인이 운영...
#    2. 페이지 94: 2. 이러닝 89 상기 내용을 살펴보면, 신청인은 청약철회 기간을 지났으므로 위 계약의 청약을 철회할 수는 없는 것으로 보인다. 피신청인은 위 ...
#    3. 페이지 3: . 이러닝···········································································...
#
# ----------------------------------------
#
#  RAG 시스템 테스트 완료!
#  실제 분쟁 상황에서 이 시스템을 활용하여 관련 사례와 법적 근거를 빠르게 찾을 수 있습니다.
